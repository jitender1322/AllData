# %%
import pandas as pd

# %%
df = pd.DataFrame([
    ["ram",34,"rajkot"],
    ["shyam",24],
    ["meet",22,"amreli"],
])

df
# Out:
#        0   1       2
# 0    ram  34  rajkot
# 1  shyam  24    None
# 2   meet  22  amreli

# %%
df.isna().sum()
# Out:
# 0    0
# 1    0
# 2    1
# dtype: int64

# %%
df.dropna(axis=1,inplace=True)

# %%
df.fillna("-",inplace=True)
df
# Out:
#        0   1       2
# 0    ram  34  rajkot
# 1  shyam  24       -
# 2   meet  22  amreli
